# %%
import pandas as pd 
import numpy as np

import warnings
warnings.filterwarnings('ignore')

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('dataset.csv')

# %%
df.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173 entries, 0 to 172
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  173 non-null    int64
#  1   TV          173 non-null    float64
#  2   Radio       173 non-null    float64
#  3   Newspaper   173 non-null    float64
#  4   Sales       173 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 6.9 KB

# %%
df.describe().transpose()
# Out:
#             count        mean        std  min   25%    50%    75%    max
# Unnamed: 0  173.0   87.000000  50.084928  1.0  44.0   87.0  130.0  173.0
# TV          173.0  143.312717  85.329340  0.7  70.6  139.3  216.8  296.4
# Radio       173.0   24.052601  14.487812  0.0  11.7   24.6   36.6   49.6
# Newspaper   173.0   31.973410  22.101807  0.3  14.2   27.3   46.0  114.0
# Sales       173.0   13.973988   5.113157  1.6  10.4   13.2   17.4   25.4

# %%
df.plot(kind='hexbin',x='TV',y='Sales',colorbar=False)
# Out:
# <Axes: xlabel='TV', ylabel='Sales'>

# %%
df.plot(kind='scatter',x='Newspaper',y='Sales',color='b')
# Out:
# <Axes: xlabel='Newspaper', ylabel='Sales'>

# %%
df.plot(kind='scatter',x='Radio',y='Sales',color='r')
# Out:
# <Axes: xlabel='Radio', ylabel='Sales'>

# %%
sns.pairplot(df,x_vars=['TV','Radio','Newspaper'],y_vars='Sales',kind='reg')

# %%
plt.figure(figsize=(12,10))
sns.heatmap(df.drop(['Unnamed: 0'],axis=1).corr(),annot=True,cmap='Blues_r')
# Out:
# <Axes: >

# %%
def check_duplicate(df):
    if df.duplicated().all():
        return 'Duplicate data present in the DataFrame'
    else:
        return 'No duplicate data found'

# %%
check_duplicate(df)
# Out:
# 'No duplicate data found'
